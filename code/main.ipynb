# %% [markdown]
# # ETL PIPELINE

# %%
# %load_ext autoreload
# %autoreload 2

import bronze_config
import silver_config
import gold_config
from bronze import bronze_process
from silver import silver_process
from gold import gold_process

# %% [markdown]
# ## Bronze Layer

# %%
bronze_process(spark)

# %% [markdown]
# ## SILVER LAYER

# %%
silver_process(spark)

# %% [markdown]
# ## GOLD LAYER

# %%
gold_process(spark)
